# %%
## Importing Lung Dataset ( IQ-OTHNCCD )
import os
from PIL import Image
from torchvision import transforms

# Path to image dataset
image_dir = "/Data/Image/IQ-OTHNCCD"

# %%
import numpy as np
import pandas as pd
